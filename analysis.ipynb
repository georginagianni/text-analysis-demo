# %% [markdown]
# # Text Analysis Demo
#
# This notebook is part of **text-analysis-demo** — a reproducible NLP pipeline for humanities researchers.
#
# Environment provisioned automatically from `codemeta.json`. No manual installation required.
#
# ---

# %% [markdown]
# ## 1. Setup — download NLTK data

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud

nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt_tab', quiet=True)

print('All dependencies loaded successfully.')

# %% [markdown]
# ## 2. Load corpus
#
# Replace the sample text below with your own corpus.

# %%
# Replace with: open('your_corpus.txt').read()
corpus = """
The study of language and its relationship to human thought has fascinated scholars
for centuries. From ancient grammarians to modern computational linguists, the
questions remain fundamentally the same: how do words carry meaning, how does
syntax shape interpretation, and what can the patterns in text tell us about the
minds and societies that produced them? Digital humanities now offers new tools
to explore these questions at scale, across vast archives that no single scholar
could read in a lifetime. Text mining, word embeddings, and frequency analysis
open new windows onto historical corpora, literary traditions, and social discourse.
"""

print(f'Corpus loaded: {len(corpus.split())} words')

# %% [markdown]
# ## 3. Word frequency analysis

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
tokens = word_tokenize(corpus.lower())
words = [w for w in tokens if w.isalpha() and w not in stop_words]

freq = Counter(words)
top_words = freq.most_common(15)

df = pd.DataFrame(top_words, columns=['word', 'count'])

fig, ax = plt.subplots(figsize=(10, 4))
ax.barh(df['word'][::-1], df['count'][::-1], color='#534AB7', alpha=0.8)
ax.set_xlabel('Frequency')
ax.set_title('Top 15 words in corpus')
ax.spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

df

# %% [markdown]
# ## 4. Word cloud

# %%
text_clean = ' '.join(words)
wc = WordCloud(width=800, height=400, background_color='white',
               colormap='viridis', max_words=80).generate(text_clean)

plt.figure(figsize=(12, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Word cloud — text-analysis-demo')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# **Environment info** — reproduced from `codemeta.json` via `generate_env.py`

# %%
import sys, nltk, pandas, matplotlib, wordcloud, json
with open('../codemeta.json') as f:
    meta = json.load(f)
print(f"Tool: {meta['name']} v{meta['version']}")
print(f"Python: {sys.version.split()[0]}")
print(f"NLTK: {nltk.__version__}  |  pandas: {pandas.__version__}  |  matplotlib: {matplotlib.__version__}")
